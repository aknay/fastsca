# %%
import os

from fastsca.data.containers.hdf5_container import Hdf5Container
from fastsca.data.plotters.trace_plotter import TracePlotter

# %%
project_folder = os.path.abspath(os.path.join(os.path.dirname("__file__"), '..', 'data'))
project_file = f'{project_folder}/aes128_arduino_uno/aes128_arduino_uno.sx'
container = Hdf5Container(project_file)

# %%
tp = TracePlotter(container)
tp.plot((0, 2))
